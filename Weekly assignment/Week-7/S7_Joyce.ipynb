# %%
#let's visualise the function
import numpy as np
import matplotlib.pyplot as plt

#Todo Question 1: Read the following gradient descent function and describe what it is doing.
def gradient_descent(function, df, x_start, learning_rate=0.1, tol=0.00001, n_iter=1000, decay_rate =0.5 ):
    iters = 0 #iteration counter
    min_point = x_start
    X = [x_start]
    Y = [function(x_start)]
    diff=0
    #Todo in question 2
    while iters < n_iter:
        diff = decay_rate*diff- learning_rate * df(min_point) #important step. #Todo in question 2
        if np.all(np.abs(diff) <= tol):
            break
        min_point += diff #important step.
        iters += 1
        X.append(min_point)
        Y.append(function(min_point))
        print("Iteration",iters,"\nX value is",min_point, "\n Y value is",function(min_point)) #Print iterations

    return min_point, X, Y

# %%
#Question 1
#Todo Question 1: initialise x_start and run gradient descent to find the minimum point
function = lambda x: (x+5)**2
df = lambda x: 2*(x+5)  #Gradient of our function
x_start = -3
ans, X, Y = gradient_descent(function, df, x_start)
print(ans)

#Plot the curve and the lines
x = np.linspace(-10,3,500)
plt.plot(x, function(x), 'b')
for i in range(0, len(X)):
    plt.plot(X[i:i+2], Y[i:i+2], 'ro-')
plt.show()
# Out:
# Iteration 1
# X value is -3.4
#  Y value is 2.5600000000000005
# Iteration 2
# X value is -3.7199999999999998
#  Y value is 1.6384000000000007
# Iteration 3
# X value is -3.976
#  Y value is 1.048576
# Iteration 4
# X value is -4.1808
#  Y value is 0.6710886400000006
# Iteration 5
# X value is -4.34464
#  Y value is 0.4294967295999999
# Iteration 6
# X value is -4.475712
#  Y value is 0.2748779069440003
# Iteration 7
# X value is -4.5805696
#  Y value is 0.17592186044416036
# Iteration 8
# X value is -4.66445568
#  Y value is 0.11258999068426263
# Iteration 9
# X value is -4.731564543999999
#  Y value is 0.07205759403792827
# Iteration 10
# X value is -4.7852516352
#  Y value is 0.04611686018427394
# Iteration 11
# X value is -4.82820130816
#  Y value is 0.029514790517935385
# Iteration 12
# X value is -4.862561046528
#  Y value is 0.018889465931478694
# Iteration 13
# X value is -4.8900488372224
#  Y value is 0.012089258196146287
# Iteration 14
# X value is -4.91203906977792
#  Y value is 0.007737125245533561
# Iteration 15
# X value is -4.929631255822336
#  Y value is 0.004951760157141479
# Iteration 16
# X value is -4.943705004657869
#  Y value is 0.0031691265005705264
# Iteration 17
# X value is -4.954964003726295
#  Y value is 0.002028240960365153
# Iteration 18
# X value is -4.963971202981036
#  Y value is 0.0012980742146336851
# Iteration 19
# X value is -4.971176962384829
#  Y value is 0.000830767497365538
# Iteration 20
# X value is -4.976941569907863
#  Y value is 0.0005316911983139607
# Iteration 21
# X value is -4.981553255926291
#  Y value is 0.0003402823669209283
# Iteration 22
# X value is -4.985242604741033
#  Y value is 0.00021778071482938887
# Iteration 23
# X value is -4.988194083792826
#  Y value is 0.00013937965749081306
# Iteration 24
# X value is -4.990555267034261
#  Y value is 8.9202980794117e-05
# Iteration 25
# X value is -4.992444213627409
#  Y value is 5.70899077082322e-05
# Iteration 26
# X value is -4.9939553709019275
#  Y value is 3.653754093326431e-05
# Iteration 27
# X value is -4.995164296721542
#  Y value is 2.3384026197285723e-05
# Iteration 28
# X value is -4.996131437377234
#  Y value is 1.4965776766261489e-05
# Iteration 29
# X value is -4.996905149901787
#  Y value is 9.578097130409553e-06
# Iteration 30
# X value is -4.9975241199214295
#  Y value is 6.129982163462114e-06
# Iteration 31
# X value is -4.9980192959371434
#  Y value is 3.923188584616456e-06
# Iteration 32
# X value is -4.998415436749715
#  Y value is 2.510840694153406e-06
# Iteration 33
# X value is -4.998732349399772
#  Y value is 1.6069380442590807e-06
# Iteration 34
# X value is -4.998985879519817
#  Y value is 1.0284403483261719e-06
# Iteration 35
# X value is -4.999188703615854
#  Y value is 6.5820182292875e-07
# Iteration 36
# X value is -4.999350962892683
#  Y value is 4.2124916667486115e-07
# Iteration 37
# X value is -4.999480770314146
#  Y value is 2.695994666720956e-07
# Iteration 38
# X value is -4.999584616251317
#  Y value is 1.7254365866984606e-07
# Iteration 39
# X value is -4.9996676930010535
#  Y value is 1.1042794154881953e-07
# Iteration 40
# X value is -4.9997341544008425
#  Y value is 7.06738825914334e-08
# Iteration 41
# X value is -4.999787323520674
#  Y value is 4.523128485859293e-08
# Iteration 42
# X value is -4.999829858816539
#  Y value is 2.8948022309559923e-08
# Iteration 43
# X value is -4.999863887053231
#  Y value is 1.8526734278069993e-08
# Iteration 44
# X value is -4.999891109642585
#  Y value is 1.1857109938042167e-08
# Iteration 45
# X value is -4.999912887714068
#  Y value is 7.588550360346986e-09
# Iteration 46
# X value is -4.999930310171254
#  Y value is 4.8566722306468306e-09
# Iteration 47
# X value is -4.9999442481370036
#  Y value is 3.1082702275743574e-09
# Iteration 48
# X value is -4.999955398509603
#  Y value is 1.989292945631743e-09
# -4.999955398509603

# %%
#Question 2
function = lambda x: x**4 - 5*(x**2) - 3*x
df = lambda x: 4*(x**3) - 10*x - 3

#Todo Question 2: Do the same with different parameters.
x_start = 2.4
ans, X, Y = gradient_descent(function, df, x_start, learning_rate=0.005)
print(ans)

x = np.linspace(-2.5,2.5,500)
#Plot the curve
plt.plot(x, function(x),'b')
for i in range(0,len(X)):
    plt.plot(X[i:i+2],Y[i:i+2],'ro-')
plt.show()

#Todo Question 2: Add Decay rate to the gradient descent function above and repeat
ans , X, Y = gradient_descent(function, df, x_start=-2, learning_rate=0.1,decay_rate=0.8)
print(ans)
# Out:
# Iteration 1
# X value is 2.25852
#  Y value is -6.260813697098766
# Iteration 2
# X value is 2.1560357379265955
#  Y value is -8.10209749015977
# Iteration 3
# X value is 2.0783913090242603
#  Y value is -9.173827865547596
# Iteration 4
# X value is 2.0177499020287275
#  Y value is -9.834219922926513
# Iteration 5
# X value is 1.9693395017152902
#  Y value is -10.258312927065624
# Iteration 6
# X value is 1.9300527649087118
#  Y value is -10.539279279414743
# Iteration 7
# X value is 1.897762470191234
#  Y value is -10.72997988820224
# Iteration 8
# X value is 1.8709546721359005
#  Y value is -10.861921023829398
# Iteration 9
# X value is 1.8485179398868168
# Iteration 51
# X value is 1.714351439111056
#  Y value is -11.200332565077705
# Iteration 52
# X value is 1.7142994040991466
#  Y value is -11.200333072398799
# Iteration 53
# X value is 1.7142539429148087
#  Y value is -11.200333459634567
# Iteration 54
# X value is 1.714214224599617
#  Y value is -11.200333755216366
# Iteration 55
# X value is 1.7141795233395383
#  Y value is -11.200333980841961
# Iteration 56
# X value is 1.714149205135079
#  Y value is -11.200334153071008
# Iteration 57
# X value is 1.714122716167384
#  Y value is -11.200334284542295
# Iteration 58
# X value is 1.7140995726430817
#  Y value is -11.200334384902385
# Iteration 59
# X value is 1.7140793519288338
#  Y value is -11.20033446151426
# Iteration 60
# X value is 1.7140616848109627
#  Y value is -11.200334519998037
# Iteration 61
# X value is 1.7140462487367438
#  Y value is -11.200334564643626
# Iteration 62
# X value is 1.7140327619123812
#  Y value is -11.200334598725616
# Iteration 63
# X value is 1.7140209781487081
#  Y value is -11.200334624743633
# Iteration 64
# X value is 1.7140106823596035
#  Y value is -11.20033464460577
# 1.7140106823596035
# Iteration 1
# X value is -0.5
#  Y value is 0.3125
# Iteration 2
# X value is -0.65
#  Y value is 0.01600625
# Iteration 3
# X value is -0.8901500000000001
#  Y value is -0.6635396141544851
# Iteration 4
# X value is -1.19816979796865
#  Y value is -1.5225663748861127
# Iteration 5
# X value is -1.408297364018835
#  Y value is -1.7581305323915268
# Iteration 6
# X value is -1.3993634376689816
#  Y value is -1.7583819847179436
# Iteration 7
# X value is -1.4026233892882052
#  Y value is -1.758416336711334
# Iteration 8
# X value is -1.4014649977008253
#  Y value is -1.758420633897206
# Iteration 9
# X value is -1.4018807139049452
#  Y value is -1.7584211891754427
# Iteration 10
# X value is -1.4017320437421106
#  Y value is -1.7584212601081664
# Iteration 11
# X value is -1.4017852785654603
#  Y value is -1.758421269206794
# Iteration 12
# X value is -1.4017662251400735
#  Y value is -1.758421270372164
# -1.4017662251400735

# %%
#Question 3
#Generate some data
np.random.seed(42)
X = np.array(sorted(list(range(5))*20)) + np.random.normal(size=100, scale=0.5)
y = np.array(sorted(list(range(5))*20)) + np.random.normal(size=100, scale=0.25)

plt.clf()
plt.scatter(X, y, color='black')
plt.show()

#Implement the gradient descent function as above for linear regression for 2 variables.
def gradient_descent_reg(X, y, b_start=0.1, w_start=5, learning_rate=0.01, tol=0.00001, n_iter=1000):
    iters = 0 #iteration counter
    b = b_start
    w = w_start
    n = X.shape[0] #we have n data points
    while iters < n_iter:
        #calculate gradient of b and w
        b_gradient = np.sum(b+w*X-y)/n  # * here does element wise multiplication
        w_gradient = np.sum((b + w  *X - y)*  X) / n #Todo
        diff_b = learning_rate * b_gradient  #Todo
        diff_w = learning_rate * w_gradient  #Todo
        if np.all(np.abs(diff_b) <= tol) and np.all(np.abs(diff_w) <= tol):
            break
        #Todo: update the values for w and b
        b -= diff_b
        w -= diff_w

        iters += 1

    return b, w

b,w = gradient_descent_reg(X, y)

plt.scatter(X, y, color='black')
plt.plot(X, w*X+b)
plt.show()
